# %% [markdown]
# Run the following line if you don't have any of the libraries

# %%
# %%bash
# pip install statsmodels pandas numpy
# Out:
# Couldn't find program: 'bash'

# %%
import pandas as pd
import matplotlib.pylab as plt
# %matplotlib inline
import data_prep
from matplotlib.pylab import rcParams
rcParams['figure.figsize'] = 15, 9

# %%
data_prep.get_lagged("./data/XLE_energy_etf.csv", n=3)
# Out:
#                  Open       High        Low      Close  Adj Close    Volume  \
# Date
# 2010-01-04  57.919998  58.810001  57.790001  58.810001  44.789688  16928400
# 2010-01-05  58.889999  59.410000  58.619999  59.290001  45.155247  17368100
# 2010-01-06  59.320000  60.180000  59.189999  60.000000  45.695988  24351900
# 2010-01-07  59.740002  60.009998  59.299999  59.910000  45.627445  17449500
# 2010-01-08  59.700001  60.349998  59.490002  60.299999  45.924469  13344300
# ...               ...        ...        ...        ...        ...       ...
# 2020-03-16  27.950001  31.120001  27.670000  27.809999  27.809999  40233600
# 2020-03-17  28.080000  29.180000  26.950001  28.000000  28.000000  45443600
# 2020-03-18  26.040001  26.580000  22.879999  23.980000  23.980000  52135800
# 2020-03-19  24.330000  25.709999  22.980000  25.610001  25.610001  52226500
# 2020-03-20  26.260000  26.840000  24.760000  25.860001  25.860001  58313200
#
#             Adj Close_1  Adj Close_2  Adj Close_3
# Date
# 2010-01-04          NaN          NaN          NaN
# 2010-01-05    44.789688          NaN          NaN
# 2010-01-06    45.155247    44.789688          NaN
# 2010-01-07    45.695988    45.155247    44.789688
# 2010-01-08    45.627445    45.695988    45.155247
# ...                 ...          ...          ...
# 2020-03-16    32.189999    29.469999    33.669998
# 2020-03-17    27.809999    32.189999    29.469999
# 2020-03-18    28.000000    27.809999    32.189999
# 2020-03-19    23.980000    28.000000    27.809999
# 2020-03-20    25.610001    23.980000    28.000000
#
# [2571 rows x 9 columns]

# %%
pd.read_csv("./data/SnP_500.csv", index_col="Date").head()
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2010-01-04  1116.560059  1133.869995  1116.560059  1132.989990  1132.989990
# 2010-01-05  1132.660034  1136.630005  1129.660034  1136.520020  1136.520020
# 2010-01-06  1135.709961  1139.189941  1133.949951  1137.140015  1137.140015
# 2010-01-07  1136.270020  1142.459961  1131.319946  1141.689941  1141.689941
# 2010-01-08  1140.520020  1145.390015  1136.219971  1144.979980  1144.979980
#
#                 Volume
# Date
# 2010-01-04  3991400000
# 2010-01-05  2491020000
# 2010-01-06  4972660000
# 2010-01-07  5270680000
# 2010-01-08  4389590000

# %%
data_prep.get_perc_return("./data/SnP_500.csv", column_name="Open")
# Out:
#             Date  %_returns
# 0     2010-01-04        NaN
# 1     2010-01-05   0.014419
# 2     2010-01-06   0.002693
# 3     2010-01-07   0.000493
# 4     2010-01-08   0.003740
# ...          ...        ...
# 2575  2020-03-27   0.021821
# 2576  2020-03-30   0.001217
# 2577  2020-03-31   0.021770
# 2578  2020-04-01  -0.044598
# 2579  2020-04-02  -0.015828
#
# [2580 rows x 2 columns]

# %%
df = pd.read_csv("./data/XLE_energy_etf.csv")
df.head() # Ensure stats are successfully read
# Out:
#          Date       Open       High        Low      Close  Adj Close    Volume
# 0  2010-01-04  57.919998  58.810001  57.790001  58.810001  44.789688  16928400
# 1  2010-01-05  58.889999  59.410000  58.619999  59.290001  45.155247  17368100
# 2  2010-01-06  59.320000  60.180000  59.189999  60.000000  45.695988  24351900
# 3  2010-01-07  59.740002  60.009998  59.299999  59.910000  45.627445  17449500
# 4  2010-01-08  59.700001  60.349998  59.490002  60.299999  45.924469  13344300

# %%
df.describe() # Shows basic statistics for data
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  2571.000000  2571.000000  2571.000000  2571.000000  2571.000000
# mean     70.764135    71.304850    70.159825    70.750829    59.788131
# std      10.544983    10.517010    10.579768    10.552985     8.750319
# min      24.330000    25.709999    22.879999    23.980000    23.980000
# 25%      64.019997    64.540001    63.375000    63.955000    55.477661
# 50%      69.699997    70.279999    69.150002    69.660004    59.805004
# 75%      76.785000    77.380001    76.235000    76.805001    65.290672
# max     101.239998   101.519997   100.980003   101.290001    83.445778
#
#              Volume
# count  2.571000e+03
# mean   1.623569e+07
# std    8.480683e+06
# min    3.104500e+06
# 25%    1.072105e+07
# 50%    1.414210e+07
# 75%    1.922790e+07
# max    6.946960e+07

# %%
df['Date'] = pd.to_datetime(df['Date'], infer_datetime_format=True)
indexeddf = df.set_index(['Date']) # Passed strings into a datetime format using to_datetime (inbuilt function in pandas)

# %%
from datetime import datetime
indexeddf.head(5) # Dates should be bold now and the word \"Date\" should be of a different row from the rest
# Out:
#                  Open       High        Low      Close  Adj Close    Volume
# Date
# 2010-01-04  57.919998  58.810001  57.790001  58.810001  44.789688  16928400
# 2010-01-05  58.889999  59.410000  58.619999  59.290001  45.155247  17368100
# 2010-01-06  59.320000  60.180000  59.189999  60.000000  45.695988  24351900
# 2010-01-07  59.740002  60.009998  59.299999  59.910000  45.627445  17449500
# 2010-01-08  59.700001  60.349998  59.490002  60.299999  45.924469  13344300

# %%
# Test plot using \"High\" of stock
dfhigh = indexeddf['High']
plt.xlabel("Date")
plt.ylabel("High of Stock")
plt.plot(dfhigh)

# %%
df10to12 = dfhigh.loc['2010-01-04':'2012-01-01'] # filtering out data up till 2012 to have a better idea of the plot
df10to12.describe()
plt.xlabel("Date")
plt.ylabel("High of Stock")
plt.plot(df10to12)

# %%
rolmean = dfhigh.rolling(window=365).mean() # Sets up the rolling window forecasts (in this case set to 1 year)
rolstd = dfhigh.rolling(window=365).std() # Forecast for residual SEs
rolema = indexeddf.High.ewm(span=365, adjust=False).mean() # Uses EMA (exponential moving average)
# Both uses standard MA formulas

print(rolmean, rolstd) # You would see that the first year is NaN because no prediction avaliable for that
# Out:
# Date
# 2010-01-04          NaN
# 2010-01-05          NaN
# 2010-01-06          NaN
# 2010-01-07          NaN
# 2010-01-08          NaN
#                 ...
# 2020-03-16    61.946192
# 2020-03-17    61.814822
# 2020-03-18    61.674712
# 2020-03-19    61.532247
# 2020-03-20    61.393699
# Name: High, Length: 2571, dtype: float64 Date
# 2010-01-04         NaN
# 2010-01-05         NaN
# 2010-01-06         NaN
# 2010-01-07         NaN
# 2010-01-08         NaN
#                 ...
# 2020-03-16    6.252694
# 2020-03-17    6.433896
# 2020-03-18    6.640109
# 2020-03-19    6.849654
# 2020-03-20    7.036503
# Name: High, Length: 2571, dtype: float64

# %%
original = plt.plot(dfhigh, color='blue', label='Original')
mean = plt.plot(rolmean, color='red', label='Rolling Mean')
resi = plt.plot(rolstd, color='black', label='Rolling Residuals')
ema = plt.plot(rolema, color='green', label='Rolling EMA')
plt.legend(loc='best')
plt.title('Rolling Mean & Residuals')
plt.show(block=False)
